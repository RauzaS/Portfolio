# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Материалы-к-проекту" data-toc-modified-id="Материалы-к-проекту-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Материалы к проекту</a></span></li><li><span><a href="#Введение" data-toc-modified-id="Введение-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Введение</a></span></li><li><span><a href="#Загрузка-,-изучение-и-предобработка-данных" data-toc-modified-id="Загрузка-,-изучение-и-предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Загрузка , изучение и предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Переименование-столбцов" data-toc-modified-id="Переименование-столбцов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Переименование столбцов</a></span></li><li><span><a href="#Дубликаты" data-toc-modified-id="Дубликаты-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Дубликаты</a></span></li><li><span><a href="#Пропуски" data-toc-modified-id="Пропуски-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Пропуски</a></span><ul class="toc-item"><li><span><a href="#Возраст----колонка-age" data-toc-modified-id="Возраст----колонка-age-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Возраст  - колонка <code>age</code></a></span></li><li><span><a href="#Баланс-пользователей---колонка-balance" data-toc-modified-id="Баланс-пользователей---колонка-balance-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Баланс пользователей - колонка <code>balance</code></a></span></li></ul></li><li><span><a href="#Изменение-типа-данных" data-toc-modified-id="Изменение-типа-данных-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Изменение типа данных</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Изучение-параметров" data-toc-modified-id="Изучение-параметров-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Изучение параметров</a></span><ul class="toc-item"><li><span><a href="#Заработная-плата-клиентов---колонка-est_salary" data-toc-modified-id="Заработная-плата-клиентов---колонка-est_salary-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Заработная плата клиентов - колонка <code>est_salary</code></a></span></li><li><span><a href="#Баланс-пользователей---колонка-balance" data-toc-modified-id="Баланс-пользователей---колонка-balance-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Баланс пользователей - колонка <code>balance</code></a></span></li><li><span><a href="#Город-проживания-пользователей---колонка-city" data-toc-modified-id="Город-проживания-пользователей---колонка-city-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Город проживания пользователей - колонка <code>city</code></a></span></li><li><span><a href="#Распределение-по-гендерному-признаку---колонка-gender" data-toc-modified-id="Распределение-по-гендерному-признаку---колонка-gender-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Распределение по гендерному признаку - колонка <code>gender</code></a></span></li><li><span><a href="#Наличие-кредитной-карты---колонка-credit_card" data-toc-modified-id="Наличие-кредитной-карты---колонка-credit_card-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Наличие кредитной карты - колонка <code>credit_card</code></a></span></li><li><span><a href="#Количество-продуктов-банка---колонка-products" data-toc-modified-id="Количество-продуктов-банка---колонка-products-4.1.6"><span class="toc-item-num">4.1.6&nbsp;&nbsp;</span>Количество продуктов банка - колонка <code>products</code></a></span></li><li><span><a href="#Оценка-собственности-клиента---колонка-equity" data-toc-modified-id="Оценка-собственности-клиента---колонка-equity-4.1.7"><span class="toc-item-num">4.1.7&nbsp;&nbsp;</span>Оценка собственности клиента - колонка <code>equity</code></a></span></li><li><span><a href="#Отток-пользователей----колонка-churn" data-toc-modified-id="Отток-пользователей----колонка-churn-4.1.8"><span class="toc-item-num">4.1.8&nbsp;&nbsp;</span>Отток пользователей  - колонка <code>churn</code></a></span></li><li><span><a href="#Возраст-пользователей---колонка-age" data-toc-modified-id="Возраст-пользователей---колонка-age-4.1.9"><span class="toc-item-num">4.1.9&nbsp;&nbsp;</span>Возраст пользователей - колонка <code>age</code></a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-4.1.10"><span class="toc-item-num">4.1.10&nbsp;&nbsp;</span>Выводы</a></span></li></ul></li><li><span><a href="#Сегментация-пользователей" data-toc-modified-id="Сегментация-пользователей-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Сегментация пользователей</a></span><ul class="toc-item"><li><span><a href="#Общая-характеристика-клиентов,-ушедших-из-банка" data-toc-modified-id="Общая-характеристика-клиентов,-ушедших-из-банка-4.2.1"><span class="toc-item-num">4.2.1&nbsp;&nbsp;</span>Общая характеристика клиентов, ушедших из банка</a></span></li><li><span><a href="#Выявление-корреляционной-зависимости-между-параметрами,-с-акцентом-на-отток-пользователей" data-toc-modified-id="Выявление-корреляционной-зависимости-между-параметрами,-с-акцентом-на-отток-пользователей-4.2.2"><span class="toc-item-num">4.2.2&nbsp;&nbsp;</span>Выявление корреляционной зависимости между параметрами, с акцентом на отток пользователей</a></span></li><li><span><a href="#Сегмент-1---по-количеству-продуктов-банка" data-toc-modified-id="Сегмент-1---по-количеству-продуктов-банка-4.2.3"><span class="toc-item-num">4.2.3&nbsp;&nbsp;</span>Сегмент 1 - по количеству продуктов банка</a></span></li><li><span><a href="#Сегмент-2---по-количеству-оценки-ценности-собственника" data-toc-modified-id="Сегмент-2---по-количеству-оценки-ценности-собственника-4.2.4"><span class="toc-item-num">4.2.4&nbsp;&nbsp;</span>Сегмент 2 - по количеству оценки ценности собственника</a></span></li><li><span><a href="#Сегмент-3---по-величине-баланса-на-счете" data-toc-modified-id="Сегмент-3---по-величине-баланса-на-счете-4.2.5"><span class="toc-item-num">4.2.5&nbsp;&nbsp;</span>Сегмент 3 - по величине баланса на счете</a></span></li><li><span><a href="#Сегмент-4---по-возрасту-(-от-52-до-58-лет)" data-toc-modified-id="Сегмент-4---по-возрасту-(-от-52-до-58-лет)-4.2.6"><span class="toc-item-num">4.2.6&nbsp;&nbsp;</span>Сегмент 4 - по возрасту ( от 52 до 58 лет)</a></span></li></ul></li><li><span><a href="#Уточнение-параметров-выделенных-сегментов" data-toc-modified-id="Уточнение-параметров-выделенных-сегментов-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Уточнение параметров выделенных сегментов</a></span><ul class="toc-item"><li><span><a href="#Сегмент1" data-toc-modified-id="Сегмент1-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Сегмент1</a></span></li><li><span><a href="#Портрет-пользователя" data-toc-modified-id="Портрет-пользователя-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Портрет пользователя</a></span></li><li><span><a href="#Сегмент-2" data-toc-modified-id="Сегмент-2-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Сегмент 2</a></span></li><li><span><a href="#Портрет-пользователя" data-toc-modified-id="Портрет-пользователя-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Портрет пользователя</a></span></li></ul></li></ul></li><li><span><a href="#Проверка-гипотез" data-toc-modified-id="Проверка-гипотез-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Проверка гипотез</a></span><ul class="toc-item"><li><span><a href="#Гипотеза-1-:-проверим-различие-возраста-клиентов,-пользующихся-2-продуктами-и-1-продуктом-банка" data-toc-modified-id="Гипотеза-1-:-проверим-различие-возраста-клиентов,-пользующихся-2-продуктами-и-1-продуктом-банка-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Гипотеза 1 : проверим различие возраста клиентов, пользующихся 2 продуктами и 1 продуктом банка</a></span></li><li><span><a href="#Гипотеза-2:-проверим-равенство-долей-оттока-в-городах-Ярославль-и-Рыбинск" data-toc-modified-id="Гипотеза-2:-проверим-равенство-долей-оттока-в-городах-Ярославль-и-Рыбинск-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Гипотеза 2: проверим равенство долей оттока в городах Ярославль и Рыбинск</a></span></li></ul></li><li><span><a href="#Рекомендации" data-toc-modified-id="Рекомендации-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Рекомендации</a></span></li><li><span><a href="#Выводы" data-toc-modified-id="Выводы-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Выводы</a></span></li></ul></div>

# %% [markdown]
# # Проект:  банки -  сегментация пользователей по потреблению

# %% [markdown]
# ## Введение
# - заказчик: маркентинговый отдел банка "Метанпром"
#
# - цель исследования: Сегментация пользователей банка по количеству используемых продуктов и подготовка портрета пользователя, покинувшего банк(изучение оттока)
#
# - конечный результат: презентация в формате .pdf, дашборд
#
# - вводные данные:
#      - представлен датасет с 10 000 пользователей на 2023 год
#      - населенные пункты: Рыбинск, Ярославль, Ростов
#      - данные клиентов:  о заработной плате, баланс счета, количество продуктов  банка,скоринговый бал, наличие кредитной карты
#      - информация о статусе- ушел из банка или нет

# %%
import pandas as pd
from matplotlib import pyplot as plt
from datetime import datetime, timedelta
import numpy as np
from scipy import stats as st
import math as mth
# %matplotlib inline
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Загрузка , изучение и предобработка данных

# %%
df=pd.read_csv('bank_scrooge.csv')
# df.head()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   USERID         10000 non-null  int64
#  1   score          10000 non-null  float64
#  2   city           10000 non-null  object
#  3   gender         10000 non-null  object
#  4   age            9974 non-null   float64
#  5   equity         10000 non-null  int64
#  6   balance        7705 non-null   float64
#  7   products       10000 non-null  int64
#  8   credit_card    10000 non-null  int64
#  9   last_activity  10000 non-null  int64
#  10  EST_SALARY     10000 non-null  float64
#  11  churn          10000 non-null  int64
# dtypes: float64(4), int64(6), object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# ### Переименование столбцов

# %%
df= df.rename(columns={'USERID':'user_id', 'EST_SALARY':'est_salary'})

# %% [markdown]
# ### Дубликаты

# %% [markdown]
# поиск явных дубликатов

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# поиск не явных дубликатов - поищем одних и тех же пользователей

# %%
df['user_id'].duplicated().sum()
# Out:
# 73

# %% [markdown]
# Всего 73 неявных дубликата, посмотрим на примере 2 пользователей

# %%
df_dup= df[df['user_id'].duplicated()] 
# df_dup.head(2)

# %%
df[df['user_id'] == 190253]
# Out:
#       user_id  score       city gender   age  equity    balance  products  \
# 231    190253  823.0    Рыбинск      М  37.0       4  373348.39         2
# 1583   190253  726.0  Ярославль      М  49.0       0        NaN         1
#
#       credit_card  last_activity  est_salary  churn
# 231             0              1   131947.92      1
# 1583            1              1   177700.78      0

# %%
df[df['user_id'] == 210662]
# Out:
#       user_id  score       city gender   age  equity     balance  products  \
# 869    210662  962.0  Ярославль      Ж  54.0       5  5069231.39         1
# 1837   210662  896.0    Рыбинск      Ж  37.0       0         NaN         2
#
#       credit_card  last_activity  est_salary  churn
# 869             1              1   955144.85      1
# 1837            0              0    90916.04      0

# %% [markdown]
# Выводы:
#
# - всего выявлено 73 неявных дубликата - это пользователи с одним и тем же id
# - не понятно, либо это старые клиенты, переехавшие с одного города в другой - на примере user_id №210662  из Рыбинска ( ей было 37 лет) и она не покинула банк, а в  в Ярославле ( уже 54 года) она покинула банк. Возможно это технические сбои в данных.
#
# Необходимо передать эту информацию  техническим службам на проверку, а из анализа на данный момент можно исключить - 73 записи не критично.

# %%
df=df.drop_duplicates(subset=['user_id'])
# df.info()

# %% [markdown]
# ### Пропуски

# %% [markdown]
# #### Возраст  - колонка `age`

# %% [markdown]
# изучим данные с пропуском возраста

# %%
data_age_isnull=df[df['age'].isnull()]
data_age_isnull
# Out:
#       user_id  score       city gender  age  equity     balance  products  \
# 1247   228075  932.0  Ярославль      М  NaN       5  7601719.20         2
# 3091   138660  836.0     Ростов      Ж  NaN       5   294315.53         2
# 4912   210674  834.0    Рыбинск      М  NaN       1   238330.52         2
# 7345   184913  829.0  Ярославль      Ж  NaN       3   188648.77         2
#
#       credit_card  last_activity  est_salary  churn
# 1247            1              1   408121.16      0
# 3091            0              1    63310.22      1
# 4912            0              1    93775.06      0
# 7345            0              1    75206.90      0

# %% [markdown]
# Выводы:
#  - всего 4 пользователя, проживающих во всех представленных городах с разным уровнем дохода и пользуются 2 продуктами банка
#  - с учетом того, что нам необходимо в дальнейшем выполнять расчеты на статзначимость данных ( возраста) и с учетом незначительного количества данных- предлагаем эти 4 строки удалить

# %%
df=df.dropna(subset=['age'])
# df.info()

# %% [markdown]
# #### Баланс пользователей - колонка `balance`

# %% [markdown]
# Посмотрим на пропуски в колонке `balance`

# %%
data_balance_isnull=df[df['balance'].isnull()]
data_balance_isnull.describe()
# Out:
#              user_id        score          age       equity  balance  \
# count    2260.000000  2260.000000  2260.000000  2260.000000      0.0
# mean   171975.568584   865.334956    42.125664     0.051770      NaN
# std     33277.188448    89.669447    11.953138     0.227525      NaN
# min    114182.000000   642.000000    18.000000     0.000000      NaN
# 25%    143067.000000   871.000000    33.000000     0.000000      NaN
# 50%    172498.500000   903.000000    40.000000     0.000000      NaN
# 75%    201354.250000   922.000000    49.000000     0.000000      NaN
# max    229145.000000   990.000000    86.000000     3.000000      NaN
#
#           products  credit_card  last_activity    est_salary        churn
# count  2260.000000  2260.000000    2260.000000  2.260000e+03  2260.000000
# mean      1.161504     0.815487       0.549115  2.267006e+05     0.005752
# std       0.401442     0.387988       0.497692  1.999817e+05     0.075642
# ...

# %%
data_balance_isnull['city'].unique()
# Out:
# array(['Рыбинск', 'Ярославль', 'Ростов'], dtype=object)

# %% [markdown]
# Посмотрим на пользователей, у которых в столбце `balance` нет пропусков

# %%
data_balance_notnull = df[df['balance'].notnull()]
data_balance_notnull.describe()
# Out:
#              user_id        score          age       equity       balance  \
# count    7663.000000  7663.000000  7663.000000  7663.000000  7.663000e+03
# mean   171659.494062   843.835835    42.907216     3.395928  8.282482e+05
# std     33818.241547    55.343192    12.237337     1.584509  1.984248e+06
# min     94561.000000   689.000000    18.000000     0.000000  0.000000e+00
# 25%    142562.000000   801.000000    33.000000     2.000000  2.954990e+05
# 50%    172667.000000   841.000000    40.000000     4.000000  5.249612e+05
# 75%    201019.000000   882.000000    52.000000     5.000000  9.808015e+05
# max    229136.000000  1000.000000    86.000000     9.000000  1.191136e+08
#
#           products  credit_card  last_activity    est_salary        churn
# count  7663.000000  7663.000000    7663.000000  7.663000e+03  7663.000000
# mean      2.080908     0.640089       0.515725  1.246424e+05     0.235678
# std       0.757959     0.480005       0.499785  1.048211e+05     0.424449
# ...

# %% [markdown]
# Выводы:
#
# пропуски по 2279 активным пользователям в возрасте 42 лет (в среднем). Пользователи находятся во всех 3-х городах. Характерные черты пользователя:
#
# - пользователи с низкой оценкой собственности (нет недвижимости и тд) - колонка `equity`
# - активные пользователи кредитной карты -`credit_card`
# - минимально пользуются продуктами банка - колонка `products`
# - имеют повышенный скоринговый бал - колонка `score`
#
# Возможно с этим связаны пропуски- не являются зарплатными клиентами, а пользуются исключительно кредитной картой.
#
# Замена этих пропусков невозможна, а удаление приведет к значительному сокращению информации - 23% от всех данных.

# %% [markdown]
# ### Изменение типа данных

# %% [markdown]
# Для дальнейшего анализа необходимо изменить категориальные данные (пол, город) в численные. Добавим новые колонки.

# %%
def name_city (name):
    if name == 'Ярославль':
        return 1
    else:
        return 0
df['Yaroslavl']= df['city'].apply(name_city)
# df.head()

# %%
def name_city (name):
    if name == 'Рыбинск':
        return 1
    else:
        return 0
df['Rubinsk']= df['city'].apply(name_city)
# df.head()

# %%
def name_city (name):
    if name == 'Ростов':
        return 1
    else:
        return 0
df['Rostov']= df['city'].apply(name_city)
# df.head()

# %%
def name_gender (value):
    if value == 'М':
        return 1
    else:
        return 0
df['gender']= df['gender'].apply(name_gender)
# df.head()

# %% [markdown]
# ### Выводы
# - исходные данные содержат датасет о 10000 пользователях банка в 3-х городах Ярославль, Ростов и Рыбинск(представлена информация о пользователе:пол, возраст, оценка зарплаты и балансе счета, активность пользователя в последний месяц, количество продуктов банка, которыми он пользуется, скоринговый балл, наличие кредитной карты и информация об оттоке пользователя)
# - данные не содержат явных дубликатов
# - данные содержат неявные дубликаты по `user_id` - 73 записи, пропуски удалены в связи с некорретными данными и незначительным количеством, не повлияющим на итоги исследования
# - отмечается пропуски в столбце `age` - всего 26 строк, пропуски удалены ввиду небольшого количества и необходимостью в дальнейшем использовать этот параметр в статанализе
# - отмечается пропуски в столбце `balance` - пропуски по 2279 активным пользователям в возрасте 42 лет (в среднем). Пользователи находятся во всех 3-х городах. Пользователи с низкой оценкой собственности (нет недвижимости и тд), активные пользователи кредитных карт, используют минимум продуктов банка. Возможно с этим связаны пропуски- не являются зарплатными клиентами, а пользуются исключительно кредитной картой. Замена этих пропусков невозможна, а удаление приведет к значительному сокращению информации - 23% от всех данных.
# - для дальнейшего анализа изменен тип данных в колонке `gender`  и добавлены новые колонки по городам.

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Изучение параметров

# %% [markdown]
# Изучим каждый параметр из данных с целью определения выбросов в данных, сегментирования по количеству используемых продуктов банка и оттока пользователей

# %% [markdown]
# #### Заработная плата клиентов - колонка `est_salary`

# %% [markdown]
# посмотрим по данным минимальное и максимальное значение  оценочной зарплаты клиентов

# %%
df['est_salary'].min(),df['est_salary'].max()
# Out:
# (2546.3, 1395064.45)

# %%
sns.histplot(data=df, hue='churn', x='est_salary', stat='density', common_norm=False, palette='flag')
plt.title('Распределение заработной платы')
plt.xlabel('заработная плата')
plt.ylabel('количество пользователей')
plt.show()

# %% [markdown]
# посмотрим на характеристики пользователей с зарплатой < 16 000 руб. Это принятый МРОТ по Ярославской области, однако в колонке `est_salary` могут быть не только зарплаты, но и какие-либо выплаты.

# %%
df[df['est_salary']< 16000].describe()
# Out:
#              user_id       score     gender        age     equity  \
# count      70.000000   70.000000  70.000000  70.000000  70.000000
# mean   176553.214286  816.471429   0.357143  45.014286   3.128571
# std     30604.109452   50.878292   0.482617  21.689838   1.658718
# min     95627.000000  725.000000   0.000000  19.000000   0.000000
# 25%    151927.750000  788.000000   0.000000  25.000000   2.000000
# 50%    177726.000000  816.000000   0.000000  32.000000   3.000000
# 75%    201118.500000  836.000000   1.000000  67.000000   4.000000
# max    228620.000000  984.000000   1.000000  77.000000   7.000000
#
#             balance   products  credit_card  last_activity    est_salary  \
# count  7.000000e+01  70.000000    70.000000      70.000000     70.000000
# mean   3.025651e+05   2.114286     0.700000       0.542857  11868.640000
# std    3.058237e+05   0.771651     0.461566       0.501757   3216.230385
# min    7.300000e+01   1.000000     0.000000       0.000000   2546.300000
# ...

# %% [markdown]
# Всего 70 человек, средний возраст -45 лет, пользуется 2 продуктами банка.

# %%
df_es=df[df['est_salary']<16000]

# %%
sns.histplot(data=df_es, hue='churn', x='est_salary', stat='density', common_norm=False, palette='flag')
plt.title('Распределение заработной платы < 16 000')
plt.xlabel('заработная плата')
plt.ylabel('количество пользователей')
plt.show()

# %% [markdown]
# Основное количество пользователей  имеют оценочный доход от 2,5 до 400 тыс рублей, рассмотрим подробнее этот диапазон

# %%
df_es_1=df[df['est_salary']<400000]

# %%
sns.histplot(data=df_es_1, hue='churn', x='est_salary', stat='density', common_norm=False, palette='flag')
plt.title('Распределение заработной платы')
plt.xlabel('заработная плата')
plt.ylabel('количество пользователей')
plt.show()

# %%
# Кастомное разбиение на группы баланса
def est_salary_groupped(row):
    out = row.copy()
    out[out<1500000] = row[row<1500000] //100000 * 100000
    out[out >= 1500000] = 1500000 // 100000 * 100000
    return out

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.pointplot(data=df.assign(gr=lambda row: est_salary_groupped(row['est_salary'])),
             x='gr', y='churn', ax=ax)
ax.axhline(df['churn'].mean(), label='Total churn', ls='--', c='r')
ax.grid(c='grey', lw=0.25)
ax.legend()
plt.title('Отток по оценочной зарплате')
plt.show()

# %% [markdown]
# В интервале з/п от 100 тыс до 220 тыс есть увеличение  оттока,
# посмотрим отток по этим пользователям

# %%
data= df.query('100000<est_salary<220000')
data['churn'].mean()
# Out:
# 0.20554962646744931

# %% [markdown]
# Выводы:
#
# Основной диапазон оценочного дохода находится в интервале 2,5-400 тыс рублей. Наблюдается большой "хвост" вправо- в сторону vip- клиентов, скорее всего. Для корректной оценки данных по этому параметру нужно пользоваться медианными значениями.
#
# В диапазоне зарплат от 100 тыс до 500 тыс рублей периодическое повышение оттока, но оно незначительно  20%-22%

# %% [markdown]
# #### Баланс пользователей - колонка `balance`

# %% [markdown]
# посмотрим диапазон баланса

# %%
df['balance'].min(), df['balance'].max()
# Out:
# (0.0, 119113552.01)

# %%
df[df['balance'] == 0]
# Out:
#       user_id  score       city  gender   age  equity  balance  products  \
# 3900   179831  730.0  Ярославль       1  18.0       0      0.0         2
# 6757   148456  813.0  Ярославль       1  20.0       2      0.0         2
#
#       credit_card  last_activity  est_salary  churn  Yaroslavl  Rubinsk  \
# 3900            1              1    64548.33      0          1        0
# 6757            1              0    23876.51      0          1        0
#
#       Rostov
# 3900       0
# 6757       0

# %%
sns.histplot(data=df, hue='churn', x='balance', stat='density', common_norm=False, palette='flag')
plt.title('Распределение  баланса клиентов банка')
plt.xlabel('баланс')
plt.ylabel('количество пользователей')
plt.show()

# %%
df_bl=df[df['balance'] < 2000000]

# %%
sns.histplot(data=df_bl, hue='churn', x='balance', stat='density', common_norm=False, palette='flag')
plt.title('Распределение  баланса клиентов банка')
plt.xlabel('баланс')
plt.ylabel('количество пользователей')
plt.show()

# %% [markdown]
# Выводы:
#
# - очень большой разброс данных от 0 до почти 120 млн.рублей
# - баланс = 0 - это молодые люди ( 2 человека 18-20 лет)
# - на диаграмме наблюдается превышение оттока при балансе 1,2-2 млн рублей - учтем этот факт при сегментации пользователей

# %%
# Кастомное разбиение на группы баланса
def balance_groupped(row):
    out = row.copy()
    out[out<1500000] = row[row<1500000] // 250000 * 250000
    out[out >= 1500000] = 1500000 // 250000 * 250000
    return out

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.pointplot(data=df.assign(gr=lambda row: balance_groupped(row['balance'])),
             x='gr', y='churn', ax=ax)
ax.axhline(df['churn'].mean(), label='Total churn', ls='--', c='r')
ax.grid(c='grey', lw=0.25)
ax.legend()
plt.title('Отток по балансу')
plt.show()

# %% [markdown]
# График показывает:
# - с 750000 баланса сильно возрастает отточность, а с 1.25млн цифры очень высокие

# %% [markdown]
# #### Город проживания пользователей - колонка `city`

# %%
df['city'].value_counts(normalize=True)
# Out:
# Ярославль    0.589943
# Рыбинск      0.267359
# Ростов       0.142699
# Name: city, dtype: float64

# %%
df.groupby('city')['churn'].mean()
# Out:
# city
# Ростов       0.187147
# Рыбинск      0.164719
# Ярославль    0.190810
# Name: churn, dtype: float64

# %% [markdown]
# Выводы:
# - больше всего пользователей проживают в Ярославле
# - уровень оттока клиентов по городам на одном уровне : 17-19%

# %% [markdown]
# #### Распределение по гендерному признаку - колонка `gender`

# %%
df['gender'].value_counts(normalize=True)
# Out:
# 1    0.500857
# 0    0.499143
# Name: gender, dtype: float64

# %% [markdown]
# #### Наличие кредитной карты - колонка `credit_card`

# %%
df['credit_card'].value_counts(normalize=True)
# Out:
# 1    0.680036
# 0    0.319964
# Name: credit_card, dtype: float64

# %% [markdown]
# #### Количество продуктов банка - колонка `products`

# %%
df['products'].value_counts(normalize=True)
# Out:
# 2    0.513454
# 1    0.333165
# 3    0.103598
# 4    0.047768
# 5    0.001915
# 0    0.000101
# Name: products, dtype: float64

# %%
data_products= df.groupby('products')\
                .agg({'gender':'mean', 'age':'mean','equity':'mean', 'balance':'median'\
                ,'credit_card':'mean','est_salary':'median', 'churn':'mean'  })
data_products
# Out:
#             gender        age    equity     balance  credit_card  est_salary  \
# products
# 0         0.000000  79.000000  3.000000         NaN     0.000000   25063.960
# 1         0.540532  42.202359  1.333636  415369.490     0.863884  142183.095
# 2         0.478116  42.753680  3.153091  516537.740     0.625711  109691.800
# 3         0.429961  45.741245  3.526265  668406.255     0.352140  105968.915
# 4         0.622363  39.782700  4.151899  939342.895     0.681435  122472.510
# 5         0.526316  36.473684  3.684211  282262.330     1.000000  106033.790
#
#              churn
# products
# 0         1.000000
# 1         0.071083
# 2         0.191953
# 3         0.288911
# 4         0.632911
# 5         0.421053

# %% [markdown]
# По сгруппированным данным:
#
# **gender** - нет никаких тенденций для объединения в группы
#
# **age** - то же самое, выделяется группа с 5 продуктами- более молодые люди
#
# **equity** - здесь можно поделить на 3 группы ( 1 продукт - ценность 1.3,  2 продукта - ценность 3.1, 3+ продукта- ценность 3.5-4.2)
#
# **credit_card** - нет условий для группировки
#
# **est_salary** - нет условий для группировки
#
# **churn** - здесь можно поделить на 3 группы ( 1 продукт - отток 7%, 2 продукта - отток 19%, 3+ продукта- отток 29-63%)
#
# **balance** - пользователи 3 и 4 продуктов имеют повышенные значения этого параметра
#
# по сгруппированным данным  можно сказать о каких-то отличиях по показателям:
# - `equity` - оценка ценности клиента
# - `churn` - отток пользователей
# - `balance` - баланс пользователя
#
# Посмотрим эти распределения

# %%
fig, ax = plt.subplots(figsize=(9, 6))
sns.kdeplot(data=df.loc[df['equity']<df['equity'].quantile(0.95)], 
             hue='products', x='equity', ax=ax,
           common_norm=False,
           fill=True,
           palette='tab10', alpha=0.05)
ax.grid(c='grey', lw=0.25)
ax.set_title('Распределение оценки собственности клиента в зависимости от количества продуктов банка у клиента')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(16, 8))
sns.pointplot(data=df, x="products", y="churn")
plt.title('Отток пользователей в зависимости от количества продуктов банка у клиента')
plt.show()

# %%
df[df['products'] == 0]
# Out:
#       user_id  score     city  gender   age  equity  balance  products  \
# 8957   147837  962.0  Рыбинск       0  79.0       3      NaN         0
#
#       credit_card  last_activity  est_salary  churn  Yaroslavl  Rubinsk  \
# 8957            0              0    25063.96      1          0        1
#
#       Rostov
# 8957       0

# %% [markdown]
# В данных есть строка с 0 значением количества продуктов банка- жительница Рыбинска, 79 лет, ушла из банка.
# Количество продуктов банка, которым она пользовалась = 3, поэтому добавим ее в третью группу

# %%
df['products'].value_counts(normalize=True)
# Out:
# 2    0.513454
# 1    0.333165
# 3    0.103598
# 4    0.047768
# 5    0.001915
# 0    0.000101
# Name: products, dtype: float64

# %% [markdown]
# Таким образом, по количеству пользователей, а так же по признакам клиентов( баланса, оценка ценности и отток) выделяется 3 группы пользователей:
# - 2 продукта ( 52% пользователей)
# - 1 продукт( 33 % пользователей)
# - 3 и более продукта ( 16% пользователей)
#
# Добавим столбец с ранжированием пользователей по количеству используемых продуктов

# %%
def users_product (value):
    if value == 2:
        return '2 продукта'
    if value == 1:
        return '1 продукт'
    if value == 3 or value ==4 or value == 5 or value == 0:
        return '3 продукта и более'
    
df['user_product'] = df['products'].apply(users_product)
# df.head()

# %% [markdown]
# #### Оценка собственности клиента - колонка `equity`

# %%
df['equity'].value_counts(normalize=True)
# Out:
# 0    0.257382
# 5    0.192381
# 4    0.185529
# 3    0.154389
# 2    0.105412
# 1    0.077698
# 6    0.016225
# 7    0.007961
# 8    0.001713
# 9    0.001310
# Name: equity, dtype: float64

# %%
df['equity'].unique()
# Out:
# array([1, 5, 0, 4, 3, 2, 6, 7, 8, 9], dtype=int64)

# %%
# Кастомное разбиение на группы баланса
def equity_groupped(row):
    out = row.copy()
    out[out<10] = row[row<10] //1 * 1
    out[out >= 10] = 10 // 1 * 1
    return out

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.pointplot(data=df.assign(gr=lambda row: equity_groupped(row['equity'])),
             x='gr', y='churn', ax=ax)
ax.axhline(df['churn'].mean(), label='Total churn', ls='--', c='r')
ax.grid(c='grey', lw=0.25)
ax.legend()
plt.title('Отток по оценке собственности клиента')
plt.show()

# %% [markdown]
# Выводы:
#
# - 25% пользователей не имеют никакой собственности
# - 54% пользователей имеют оценку ценности от 3 до 5
# - владельцы 3-х и более объектов имеют повышенный отток

# %% [markdown]
# #### Отток пользователей  - колонка `churn`

# %%
df['churn'].mean()
# Out:
# 0.18331149853874837

# %% [markdown]
# отток составляет 18%

# %% [markdown]
# #### Возраст пользователей - колонка `age`

# %%
fig, ax = plt.subplots(figsize=(16, 8))
sns.histplot(data=df_bl, hue='churn', x='age', stat='density', common_norm=False, palette='flag')
plt.title('Распределение  возраста клиентов банка')
plt.xlabel('возраст')
plt.ylabel('количество пользователей')
plt.show()

# %%
def age_rang (value):
    if 18 < value < 30:
        return 'молодой'
    if 30<= value < 60:
        return 'средний'
    if  value > 60:
        return 'старший'
df['age_range']= df['age'].apply(age_rang)

# %%
df['age_range'].value_counts(normalize=True)
# Out:
# средний    0.778713
# молодой    0.116083
# старший    0.105204
# Name: age_range, dtype: float64

# %%
df.query('25 < age <35').describe()
# Out:
#              user_id        score       gender          age       equity  \
# count    2514.000000  2514.000000  2514.000000  2514.000000  2514.000000
# mean   169724.483294   851.841289     0.579952    30.790374     2.662689
# std     34216.056089    65.463530     0.493664     2.439766     1.986821
# min     94561.000000   648.000000     0.000000    26.000000     0.000000
# 25%    139822.000000   805.000000     0.000000    29.000000     0.000000
# 50%    169250.000000   858.000000     1.000000    31.000000     3.000000
# 75%    198807.750000   901.000000     1.000000    33.000000     4.000000
# max    229054.000000  1000.000000     1.000000    34.000000     9.000000
#
#             balance     products  credit_card  last_activity    est_salary  \
# count  1.938000e+03  2514.000000  2514.000000    2514.000000  2.514000e+03
# mean   6.399859e+05     1.861973     0.728321       0.550119  1.285443e+05
# std    1.001718e+06     0.807620     0.444914       0.497581  1.384123e+05
# ...

# %%
# Кастомное разбиение на группы баланса
def age_groupped(row):
    out = row.copy()
    out[out<90] = row[row<90] // 5 * 5
    out[out >= 90] = 90 // 5 * 5
    return out

# %%
fig, ax = plt.subplots(figsize=(12, 6))
sns.pointplot(data=df.assign(gr=lambda row: age_groupped(row['age'])),
             x='gr', y='churn', ax=ax)
ax.axhline(df['churn'].mean(), label='Total churn', ls='--', c='r')
ax.grid(c='grey', lw=0.25)
ax.legend()
plt.title('Отток по возрасту клиентов')
plt.show()

# %% [markdown]
# Выводы:
# - Основные пользователи (77% ) - от 30 до 60 лет - люди среднего возраста. Молодежь и люди старшего поколения имеют почти одинаковую долю- 10-11%
# - В диапазонах  22-33 лет и 52-58 лет наблюдается увеличение оттока, учтем эти данные при выполнении сегментации.

# %% [markdown]
# #### Выводы
#  - таким образом, в финальном датасете остается 9923  пользователя. Всего удалено записей по 77 пользователям, что составляет около 0.8 %.
#  - пользователи проживают в 3-х городах - Ярославле ( около 59%),Рыбинске (27%) и Ростове(14%)
#  - по гендерному признаку - пользователи разделены 50/50
#  - почти 70% пользователей пользуются кредитной картой
#  - 51% пользователей пользуются 2 продуктами банка, 33%-  одним продуктом, 16% - тремя и более продуктами
#  - объекты недвижимости пользователей доходит до 9, 63% пользователей имеют от 2 до 5  объектов, 25% - не имеют в собственности ничего
#  - отток составляет 18%
#  - возрастной диапазон пользователей от 18 до 86 лет, доля старшего поколения( более 60 лет) составляет 11%
#  - заработная плата варьирует от 2,5 тыс до 1 млн 395 тыс.

# %% [markdown]
# ### Сегментация пользователей

# %% [markdown]
# #### Общая характеристика клиентов, ушедших из банка

# %%
df.groupby('churn'). agg('mean')
# Out:
#              user_id       score    gender        age    equity       balance  \
# churn
# 0      171900.133144  845.436451  0.467300  43.016288  2.380923  7.338286e+05
# 1      170980.103903  863.416163  0.650357  41.450247  3.763057  1.134458e+06
#
#        products  credit_card  last_activity     est_salary  Yaroslavl  \
# churn
# 0      1.758268     0.708909       0.483218  147795.992004   0.584526
# 1      2.376031     0.551402       0.702034  148289.702221   0.614074
#
#         Rubinsk    Rostov
# churn
# 0      0.273445  0.142029
# 1      0.240242  0.145684

# %% [markdown]
# посмотрим на характеристику "ушедших" поподробнее

# %%
df[df['churn'] == 1].describe()
# Out:
#              user_id        score       gender          age       equity  \
# count    1819.000000  1819.000000  1819.000000  1819.000000  1819.000000
# mean   170980.103903   863.416163     0.650357    41.450247     3.763057
# std     35291.182757    49.620984     0.476988    11.176459     1.585980
# min     94561.000000   706.000000     0.000000    18.000000     0.000000
# 25%    141304.000000   828.000000     0.000000    32.000000     3.000000
# 50%    170532.000000   866.000000     1.000000    39.000000     4.000000
# 75%    201399.500000   898.000000     1.000000    52.000000     5.000000
# max    229058.000000  1000.000000     1.000000    79.000000     9.000000
#
#             balance     products  credit_card  last_activity    est_salary  \
# count  1.806000e+03  1819.000000  1819.000000    1819.000000  1.819000e+03
# mean   1.134458e+06     2.376031     0.551402       0.702034  1.482897e+05
# std    2.034446e+06     0.923592     0.497488       0.457490  1.229322e+05
# ...

# %% [markdown]
# Выводы:
#
# Ушедшие клиенты, в отличие от оставшихся, характеризуются:
# - преимущественно мужчины, 41 год
# - более высокой оценкой собственности ( 3,7 против 2,4)
# - более активно пользовались услугами банка в последний месяц (0,70 против 0,48)
# - количество продуктов банка 2,4 против 1,8
# - баланс на счете выше

# %% [markdown]
# ####  Выявление корреляционной зависимости между параметрами, с акцентом на отток пользователей

# %% [markdown]
# Для нахождения зависимостей между всеми параметрами используем метод ранговой корреляции Спирмена

# %%
df.corr(method='spearman')
# Out:
#                 user_id     score    gender       age    equity   balance  \
# user_id        1.000000  0.008588  0.030232  0.019739  0.007486  0.027121
# score          0.008588  1.000000  0.018536 -0.019892  0.020496  0.416941
# gender         0.030232  0.018536  1.000000 -0.189671 -0.019057  0.019439
# age            0.019739 -0.019892 -0.189671  1.000000  0.016039  0.222268
# equity         0.007486  0.020496 -0.019057  0.016039  1.000000  0.550253
# balance        0.027121  0.416941  0.019439  0.222268  0.550253  1.000000
# products      -0.001708 -0.085443 -0.042540  0.030350  0.456417  0.197103
# credit_card    0.003073 -0.076661  0.126264 -0.118481 -0.166277 -0.167100
# last_activity -0.030683 -0.027204 -0.013296 -0.023051 -0.000867  0.016117
# est_salary    -0.001421  0.246046  0.119445  0.014778 -0.182347  0.337216
# churn         -0.007379  0.096978  0.141658 -0.045850  0.267673  0.202673
# Yaroslavl      0.011145  0.033589  0.021713 -0.058515 -0.020543  0.051019
# ...

# %%
f,ax = plt.subplots(figsize=(30,8))

sns.heatmap(
    df.corr(method='spearman'),
    annot=True,
    fmt=".1%",
    vmin=-1,
    vmax=1,
    cmap='RdBu',
    linewidths=0.1,
    cbar=True,
    square=True
)
plt.show()

# %% [markdown]
# Выводы:
#
# - По тепловой карте можно сказать, что явных корреляций между оттоком пользователей и параметрами не наблюдается.
# - В лидерах по зависимости те же три параметра: количество объектов у пользователей, количество продуктов банка и баланс у пользователя - чем больше этих параметров, тем выше отток. Однако, коэффициенты небольшие( менее 30%), поэтому это пока трудно назвать зависимостями.
#
# Попробуем выделить сегменты с наибольшим оттоком по этим трем направлениям:
# - по количеству используемых продуктов банка
# - по количеству оценки ценности собственника
# - по величине баланса на счете
#
# Рассмотрим еще один сегмент- по возрасту
#
# - по возрасту в диапазоне 47-58 лет

# %% [markdown]
# #### Сегмент 1 - по количеству продуктов банка

# %%
sns.catplot(data=df, x='user_product', y='churn', kind='bar', 
            order=sorted(df['user_product'].dropna().unique(), key=lambda x: x[0]))
plt.ylabel('отток')
plt.title ('Распределение оттока по пользователям(в зависимости от количества продуктов банка)')
plt.show()

# %%
df_segm_1= df[df['products']>=3]
df_segm_1.describe()
# Out:
#              user_id        score       gender          age       equity  \
# count    1521.000000  1521.000000  1521.000000  1521.000000  1521.000000
# mean   172112.616700   850.301775     0.491124    43.768573     3.723208
# std     34321.024189    56.623227     0.500086    12.560447     1.554804
# min     95384.000000   689.000000     0.000000    19.000000     0.000000
# 25%    143385.000000   806.000000     0.000000    34.000000     3.000000
# 50%    173532.000000   848.000000     0.000000    41.000000     4.000000
# 75%    201158.000000   893.000000     1.000000    53.000000     5.000000
# max    229058.000000  1000.000000     1.000000    83.000000     9.000000
#
#             balance     products  credit_card  last_activity    est_salary  \
# count  1.493000e+03  1521.000000  1521.000000    1521.000000  1.521000e+03
# mean   1.078189e+06     3.336621     0.462853       0.539776  1.349505e+05
# std    1.656084e+06     0.498452     0.498782       0.498579  1.217957e+05
# ...

# %% [markdown]
# Выводы:
#
# По признаку- количество используемых продуктов банка  наблюдается тенденция повышения оттока пользователей у тех, кто пользуется 3-мя продуктами и более. Отток 39,8%.

# %% [markdown]
# #### Сегмент 2 - по количеству оценки ценности собственника

# %%
sns.catplot(data=df, x='equity', y='churn', kind='bar', color='#a1c9f4')
plt.ylabel('отток')
plt.title ('Распределение оттока по пользователям(в зависимости от оценки собственности клиента)')
plt.show()

# %%
df_segm_2=df.query('equity>=6')
df_segm_2.describe()
# Out:
#              user_id       score      gender         age      equity  \
# count     270.000000  270.000000  270.000000  270.000000  270.000000
# mean   173924.037037  867.718519    0.555556   42.318519    6.562963
# std     35512.474952   47.482206    0.497827   12.203450    0.814437
# min     95627.000000  746.000000    0.000000   19.000000    6.000000
# 25%    143544.250000  835.000000    0.000000   32.000000    6.000000
# 50%    175496.000000  866.000000    1.000000   40.000000    6.000000
# 75%    203356.750000  900.000000    1.000000   51.000000    7.000000
# max    228863.000000  993.000000    1.000000   75.000000    9.000000
#
#             balance    products  credit_card  last_activity    est_salary  \
# count  2.700000e+02  270.000000   270.000000     270.000000  2.700000e+02
# mean   8.890137e+05    2.337037     0.585185       0.588889  1.262812e+05
# std    9.645551e+05    0.964673     0.493605       0.492949  1.139120e+05
# ...

# %% [markdown]
# Выводы:
# - По признаку- оценка ценности пользователя наблюдается тенденсция к повышению оттока у владельцев 6 и более едениц ценности (недвижимость, авто и т.д). отток составляет 40%.
#
# - Однако, количество пользователей в этом сегменте незначительно и составляет всего 270 человек. В последующем уточнении сегментов попробуем применить этот параметр для детализации других сегментов.

# %% [markdown]
# #### Сегмент 3 - по величине баланса на счете

# %%
sns.histplot(data=df_bl, hue='churn', x='balance', stat='density', common_norm=False, palette='flag')
plt.title('Распределение  баланса клиентов банка')
plt.xlabel('баланс')
plt.ylabel('количество пользователей')
plt.show()

# %%
df_segm_3=df.query('1200000 < balance')
df_segm_3.describe()
# Out:
#              user_id        score       gender          age       equity  \
# count    1333.000000  1333.000000  1333.000000  1333.000000  1333.000000
# mean   173194.682671   885.855214     0.546137    45.760690     4.210053
# std     35318.215534    54.541655     0.498054    11.422958     1.024909
# min     96404.000000   731.000000     0.000000    23.000000     0.000000
# 25%    144569.000000   853.000000     0.000000    36.000000     4.000000
# 50%    175343.000000   897.000000     1.000000    43.000000     4.000000
# 75%    203512.000000   925.000000     1.000000    55.000000     5.000000
# max    229058.000000  1000.000000     1.000000    84.000000     9.000000
#
#             balance     products  credit_card  last_activity    est_salary  \
# count  1.333000e+03  1333.000000  1333.000000    1333.000000  1.333000e+03
# mean   2.418202e+06     2.411103     0.489122       0.529632  2.043960e+05
# std    4.376705e+06     0.862427     0.500069       0.499308  1.861200e+05
# ...

# %% [markdown]
# Выводы:
# - По величине баланса на счете у пользователя наблюдается увеличение оттока у тех, кто владеет балансом более 1 млн 200 тыс рублей. Отток =42,6%.

# %% [markdown]
# #### Сегмент 4 - по возрасту ( от 52 до 58 лет)

# %%
sns.histplot(data=df_bl, hue='churn', x='age', stat='density', common_norm=False, palette='flag')
plt.title('Распределение  возраста клиентов банка')
plt.xlabel('возраст')
plt.ylabel('количество пользователей')
plt.show()

# %%
df_segm_4=df.query('52 < age < 58')
df_segm_4.describe()
# Out:
#              user_id       score      gender         age      equity  \
# count     787.000000  787.000000  787.000000  787.000000  787.000000
# mean   172874.640407  846.759848    0.445997   54.974587    2.716645
# std     33884.677533   65.229226    0.497391    1.438958    1.990375
# min     99726.000000  649.000000    0.000000   53.000000    0.000000
# 25%    143322.500000  800.000000    0.000000   54.000000    1.000000
# 50%    174284.000000  850.000000    0.000000   55.000000    3.000000
# 75%    201770.000000  899.000000    1.000000   56.000000    4.000000
# max    229058.000000  992.000000    1.000000   57.000000    9.000000
#
#             balance    products  credit_card  last_activity    est_salary  \
# count  6.170000e+02  787.000000   787.000000     787.000000  7.870000e+02
# mean   9.920301e+05    1.919949     0.598475       0.510801  1.313158e+05
# std    1.969814e+06    0.786299     0.490518       0.500201  1.320866e+05
# ...

# %% [markdown]
# Выводы:
# - По графику отмечается 2 участка с повышенным значением оттока, пользователи более молодого возраста 25-35 лет - здесь превышение оттока не явное, а вот пользователи более старшего поколения 52-58 лет показывают увеличение оттока с 18 до 29%.

# %% [markdown]
# ### Уточнение параметров выделенных сегментов

# %% [markdown]
# На этом шаге попробуем применить к ранее выделенным сегментам с увеличенным оттоком пользователей дополнительные параметры для  сужения диапазона пользователей и выделим финальные сегменты.

# %% [markdown]
# #### Сегмент1

# %% [markdown]
# На ранее выделенный сегмент по количеству продуктов банка (численностью 1521 человек, отток 39,8%) добавим ограничение по значению баланса  от 1,2 млн. Численность сегмента уменьшилась до 466 человек, отток составляет 59%.

# %%
segment_1=df_segm_1.query('1200000 < balance')
segment_1.describe()
# Out:
#              user_id        score      gender         age      equity  \
# count     466.000000   466.000000  466.000000  466.000000  466.000000
# mean   173210.379828   881.690987    0.515021   46.439914    4.236052
# std     36882.221743    57.611332    0.500311   11.550992    1.077666
# min     99111.000000   731.000000    0.000000   25.000000    0.000000
# 25%    142479.000000   839.250000    0.000000   37.000000    4.000000
# 50%    173903.000000   895.000000    1.000000   43.000000    4.000000
# 75%    208081.500000   926.750000    1.000000   55.000000    5.000000
# max    229058.000000  1000.000000    1.000000   82.000000    8.000000
#
#             balance    products  credit_card  last_activity    est_salary  \
# count  4.660000e+02  466.000000   466.000000     466.000000  4.660000e+02
# mean   2.248872e+06    3.442060     0.465665       0.551502  1.908939e+05
# std    2.567585e+06    0.514177     0.499356       0.497875  1.614587e+05
# ...

# %% [markdown]
# #### Портрет пользователя

# %% [markdown]
# Таким образом, сегмент 1 имеет характеристики:
# - может быть как мужчина так и женщина, возраст 46 лет
# - количество продуктов банка более 3
# - оценка собственности -4
# - пользователи имеют на счете  более 1,2 млн.рублей
# - численность 466 человек
# - отток-59%

# %% [markdown]
# #### Сегмент 2

# %% [markdown]
# Это ранее рассмотренный сегмент 4 - по возрасту от 52 до 58 лет. По этому параметру корректировку сделали с учетом оценки ценности клиента - колонка `equity`, приняли в расчете >=3.

# %%
segment_2=df_segm_4[df_segm_4['equity']>=3]
segment_2.describe()
# Out:
#              user_id       score      gender         age      equity  \
# count     449.000000  449.000000  449.000000  449.000000  449.000000
# mean   175162.547884  850.665924    0.465479   55.055679    4.233853
# std     33680.070010   54.463739    0.499363    1.443588    1.009382
# min     99726.000000  706.000000    0.000000   53.000000    3.000000
# 25%    148479.000000  807.000000    0.000000   54.000000    3.000000
# 50%    177068.000000  851.000000    0.000000   55.000000    4.000000
# 75%    203587.000000  893.000000    1.000000   56.000000    5.000000
# max    229058.000000  983.000000    1.000000   57.000000    9.000000
#
#             balance    products  credit_card  last_activity    est_salary  \
# count  4.490000e+02  449.000000   449.000000     449.000000  4.490000e+02
# mean   1.200098e+06    2.155902     0.552339       0.521158  1.150755e+05
# std    2.257087e+06    0.760473     0.497808       0.500109  1.098229e+05
# ...

# %% [markdown]
# #### Портрет пользователя

# %% [markdown]
# Параметры пользователей сегмента 2:
# - преимущественно женщина, средний возраст 55 лет
# - пользователи в возрасте от 52 до 58 лет
# - пользуется двумя продуктами банка
# - оценка собственности около 4
# - численность 449 человек
# - отток 38%

# %% [markdown]
# ## Проверка гипотез

# %% [markdown]
# ### Гипотеза 1 : проверим различие возраста клиентов, пользующихся 2 продуктами и 1 продуктом банка

# %% [markdown]
#  - Н0 - возраст пользователей, пользующихся одним или двумя продуктами, одинаковый
#  - Н1 - возраст пользователей , пользующихся одним или двумя продуктами, не одинаковый

# %%
df['products'].value_counts()
# Out:
# 2    5095
# 1    3306
# 3    1028
# 4     474
# 5      19
# 0       1
# Name: products, dtype: int64

# %% [markdown]
# Количество пользователей одним продуктом = 3306
# Количество пользователей двумя продуктами = 5095

# %%
fig, ax = plt.subplots(figsize=(10,5))
sns.distplot(df[df['products'] == 1]['age'], label = 'один продукт')
sns.distplot(df[df['products'] == 2]['age'], label = 'два продукта')
plt.ylabel('количество пользователей')
plt.title ('Возраст клиентов от количества используемых продуктов банка')
plt.show()

# %% [markdown]
# Для проверки гипотезы о сравнении двух средних используем ttest. На входе имеем два списка, разной численности - клиенты, пользующиеся 1 продуктом -3306 и двумя продуктами -5095 человек. Нам нужно понять, насколько средние арифметические этих двух групп одинаковые.
#
# Исходные данные должны быть нормально распределены, что мы видим на графике.t-test позволяет оценить средние арифметические двух выборок (попарное сравнение)

# %%
prod_1 = df[df['products']==1]['age']
prod_2 = df[df['products']==2]['age']

alpha = 0.05
results = st.stats.ttest_ind(prod_1, prod_2, equal_var=False)

print('р-значение:', results.pvalue)

if results.pvalue < alpha:
    print('Отвегаем нулевую гипотезу')
else:
    print('Не получилось отвергнуть нулевую гипотезу')
# Out:
# р-значение: 0.04054523646600757
# Отвегаем нулевую гипотезу

# %% [markdown]
# Гипотеза о равенстве возраста при использовании одного продукта или двух продуктов банка - не подтвердилась.

# %% [markdown]
# ### Гипотеза 2: проверим равенство долей оттока в городах Ярославль и Рыбинск

# %% [markdown]
#  - Н0 - доля оттока пользователей в городах Ярославль и Рыбинск одинаковые
#  - Н1 - доля оттока пользователей в городах Ярославль и Рыбинск не одинаковые

# %% [markdown]
# Проведем z-test (проверка гипотезы о равенстве долей). Введем данные о количестве пользователей в городах и количестве пользователей, ушедших из банка.

# %% [markdown]
# количество пользователей в Ярославле

# %%
counts_0 = df['Yaroslavl'].sum()
counts_0
# Out:
# 5854

# %% [markdown]
# отток в Ярославле

# %%
churn_0 = df[df['city'] =='Ярославль']['churn'].sum()
churn_0
# Out:
# 1117

# %% [markdown]
# количество пользователей в Рыбинске

# %%
counts_1 = df['Rubinsk'].sum()
counts_1
# Out:
# 2653

# %% [markdown]
# отток в Рыбинске

# %%
churn_1 = df[df['city'] =='Рыбинск']['churn'].sum()
churn_1
# Out:
# 437

# %%
alpha = 0.05 

p1=churn_0/ counts_0 
p2=churn_1/ counts_1
p_combined=(churn_0+churn_1) / (counts_0+counts_1)
difference = p1-p2
z_value =difference / mth.sqrt(p_combined * (1 - p_combined) * (1/counts_0 + 1/counts_1)) 

distr=st.norm(0,1) 

p_value = (1 - distr.cdf(abs(z_value))) * 2  
print('p-значение: ', p_value)

if p_value < alpha: 
    print('Отвергаем нулевую гипотезу: между долями есть значимая разница')
else:
    print(
        'Не получилось отвергнуть нулевую гипотезу, нет оснований считать доли разными'
    )
# Out:
# p-значение:  0.003913439178869327
# Отвергаем нулевую гипотезу: между долями есть значимая разница

# %% [markdown]
# z-test позволяет определить среднее значение распределения двух выборок, на входе выборка клиентов разных городов  ( Ярославля и Рыбинска) и список оттока по этим же городам. z-test может определить насколько пропорции оттока по этим двум городам статистически равные.
#
# Гипотеза о равенстве долей оттока в городах Ярославль и Рыбинск не подтвердилась

# %% [markdown]
# ## Рекомендации

# %% [markdown]
# По пользователям сегмента 1:
# - используют более 3-х продуктов банка, возможно это кредиты на разные нужды (ипотеки, потребительские кредиты, вклады) - необходимо рассмотреть варианты рефинансирования при большом количестве кредитов для удержания клиентов
#
# По пользователям сегмента 2:
# - люди старшего возраста, отток возможно связан с прекращением обслуживания зарплатных счетов в связи с выходом на пенсию. Можно рассмотреть открытие вкладов для пенсионеров, предложить использование инвестиций, льготное кредитование, повышенный кэшбэк.
#
# Дополнительно:
# - необходимо обратить внимание на клиентов молодого возраста от 25 до 35 лет. Наблюдается незначительное превышение оттока. Для предупреждения повышения этого показателя возможно рассмотреть комплекс мероприятий для молодых клиентов- это и кредиты для учебы, возможно какие-либо акции для привлечения молодых людей - пока с минимальными зарплатами, рассматривать их как потенциально активных пользователей продуктов банка в будущем.

# %% [markdown]
# ## Выводы

# %% [markdown]
# Выполнен анализ данных банка "Метанпром"  по состоянию на 2023 год.
# - Всего в исследовании рассмотрены данные о  9923 пользователя. Всего удалено записей по 77 пользователям, что составляет менее 1%.
# - пользователи проживают в 3-х городах - Ярославле ( около 59%),Рыбинске (27%) и Ростове(14%)
# - по гендерному признаку - пользователи разделены 50/50
# - почти 70% пользователей пользуются кредитной картой
# - 51% пользователей пользуются 2 продуктами банка, 33%- одним продуктом, 16% - тремя и более продуктами
# - оценка ценности пользователей доходит до 9, 63% пользователей имеют от 2 до 5 объектов, 25% - не имеют в собственности ничего
# - отток составляет 18%
# - возрастной диапазон пользователей от 18 до 86 лет, доля старшего поколения( более 60 лет) составляет 12%
# - заработная плата варьирует от 2,5 тыс до 1 млн 395 тыс.
#
# Выполнена проверка гипотез:
# - 1 гипотеза о сравнении возраста клиента пользующимся одним продуктом банка и двумя продуктами банкаю Для сравнения двух средних использовали ttest. Нулевая гипотеза о равенстве возраста клиента не подтвердилась.
#
# - 2 гипотеза о сравнении доли оттока в разных городах ( Ярославль и Рыбинск). Для оценки доли использовали z-test. Нулевая гипотеза о равенстве долей не подтвердилась.
#
# Выполнена сегментация пользователей по оттоку, всего рассмотрено 4 сегмента, после дополнительного анализа в финальном варианте оставлено 2 сегмента пользователей. Портрет пользователей, покинувших банк:
#
# **сегмент 1**
# - может быть как мужчина так и женщина, возраст 46 лет
# - количество продуктов банка более 3
# - оценка собственности -4
# - пользователи имеют на счете более 1,2 млн.рублей
# - численность 466 человек
# - отток-59%
#
# **сегмент 2**
# - преимущественно женщина, средний возраст 55 лет
# - пользователи в возрасте от 52 до 58 лет
# - пользуется двумя продуктами банка
# - оценка собственности около 4
# - численность 449 человек
# - отток 38%
#
# Таким образом, исходный суммарный отток = 18%, отток в предложенных сегментах 59% и 38%.
